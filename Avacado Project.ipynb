# %%
#Importing the Libraries
import numpy as np
import pandas as pd
import matplotlib 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#read the csv file
df=pd.read_csv("avacardo.csv")

# %%
df.head()
# Out:
#    No        Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0   0  27-12-2015          1.33      64236.62  1036.74   54454.85   48.16
# 1   1  20-12-2015          1.35      54876.98   674.28   44638.81   58.33
# 2   2  13-12-2015          0.93     118220.22   794.70  109149.67  130.50
# 3   3  06-12-2015          1.08      78992.15  1132.00   71976.41   72.58
# 4   4  29-11-2015          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9505.56     9408.07       97.49          0.0  conventional  2015  Albany
# 2     8145.35     8042.21      103.14          0.0  conventional  2015  Albany
# 3     5811.16     5677.40      133.76          0.0  conventional  2015  Albany
# 4     6183.95     5986.26      197.69          0.0  conventional  2015  Albany

# %%
df.shape
# Out:
# (1517, 14)

# %%
df.isnull().sum()
# Out:
# No              0
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %%
#dropping the index column as it has no effect on the dataset
df.drop('No', inplace=True, axis=1)

# %%
df
# Out:
#             Date  AveragePrice  Total Volume        4046        4225  \
# 0     27-12-2015          1.33      64236.62     1036.74    54454.85
# 1     20-12-2015          1.35      54876.98      674.28    44638.81
# 2     13-12-2015          0.93     118220.22      794.70   109149.67
# 3     06-12-2015          1.08      78992.15     1132.00    71976.41
# 4     29-11-2015          1.28      51039.60      941.48    43838.39
# 5     22-11-2015          1.26      55979.78     1184.27    48067.99
# 6     15-11-2015          0.99      83453.76     1368.92    73672.72
# 7     08-11-2015          0.98     109428.33      703.75   101815.36
# 8     01-11-2015          1.02      99811.42     1022.15    87315.57
# 9     25-10-2015          1.07      74338.76      842.40    64757.44
# 10    18-10-2015          1.12      84843.44      924.86    75595.85
# 11    11-10-2015          1.28      64489.17     1582.03    52677.92
# 12    04-10-2015          1.31      61007.10     2268.32    49880.67
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1517 entries, 0 to 1516
# Data columns (total 13 columns):
# Date            1517 non-null object
# AveragePrice    1517 non-null float64
# Total Volume    1517 non-null float64
# 4046            1517 non-null float64
# 4225            1517 non-null float64
# 4770            1517 non-null float64
# Total Bags      1517 non-null float64
# Small Bags      1517 non-null float64
# Large Bags      1517 non-null float64
# XLarge Bags     1517 non-null float64
# type            1517 non-null object
# year            1517 non-null int64
# region          1517 non-null object
# dtypes: float64(9), int64(1), object(3)
# memory usage: 154.1+ KB

# %%
df.describe()
# Out:
#        AveragePrice  Total Volume          4046          4225          4770  \
# count   1517.000000  1.517000e+03  1.517000e+03  1.517000e+03  1.517000e+03
# mean       1.074990  1.601879e+06  6.464387e+05  6.114375e+05  5.040550e+04
# std        0.188891  4.433143e+06  1.947614e+06  1.672906e+06  1.377812e+05
# min        0.490000  3.875074e+04  4.677200e+02  1.783770e+03  0.000000e+00
# 25%        0.980000  1.474700e+05  2.040034e+04  4.147606e+04  9.112500e+02
# 50%        1.080000  4.027919e+05  8.175117e+04  1.186649e+05  7.688170e+03
# 75%        1.190000  9.819751e+05  3.775785e+05  4.851503e+05  2.916730e+04
# max        1.680000  4.465546e+07  1.893304e+07  1.895648e+07  1.381516e+06
#
#          Total Bags    Small Bags    Large Bags    XLarge Bags         year
# count  1.517000e+03  1.517000e+03  1.517000e+03    1517.000000  1517.000000
# mean   2.935974e+05  2.487736e+05  4.264205e+04    2181.771074  2015.162821
# ...

# %%
df['region'].value_counts()
# Out:
# California             76
# Albany                 67
# BaltimoreWashington    65
# Boise                  65
# Boston                 62
# Atlanta                54
# PhoenixTucson          52
# BuffaloRochester       51
# Spokane                49
# Columbus               47
# NewYork                44
# Jacksonville           41
# Detroit                40
# SouthCentral           39
# SanDiego               38
# West                   36
# Tampa                  34
# Louisville             34
# Charlotte              31
# Portland               30
# Houston                29
# NorthernNewEngland     29
# WestTexNewMexico       27
# Nashville              25
# TotalUS                25
# Denver                 24
# SouthCarolina          24
# GrandRapids            23
# Chicago                23
# Pittsburgh             22
# RichmondNorfolk        21
# Orlando                21
# HarrisburgScranton     19
# Syracuse               19
# Midsouth               18
# ...

# %%
#checking the value counts of each type
df.type.value_counts()
# Out:
# conventional    1517
# Name: type, dtype: int64

# %% [markdown]
# We can remove this column as all the avacado's are of same type

# %%
df.year.value_counts()
# Out:
# 2015    1270
# 2016     247
# Name: year, dtype: int64

# %%
df.isnull().sum()
# Out:
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %%
plt.figure(figsize=(24,15))
sns.barplot(x='region',y='AveragePrice',data=df)
plt.xticks(rotation=90)
plt.xlabel('Region')
plt.ylabel('Average Price')
plt.title('ration of Price and Region')
# Out:
# Text(0.5,1,'ration of Price and Region')

# %% [markdown]
# Above graph shows that HartfordSpringfield ,SanFrancisco and NewYork have higher average price as compared to other regions.

# %%
#plotting histogram for univariate analysis and checking the Normal Distribution
df.hist(figsize=(20,20), grid = True, layout = (4,4), bins = 30)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002C6099F0978>,
# ...
#       dtype=object)

# %%
#Making the categorical data into numercial for better EDA

from sklearn.preprocessing import LabelEncoder,StandardScaler

column = ['region']
le = LabelEncoder()
for i in column:
    df[i] = le.fit_transform(df[i].astype(str))

print(df.dtypes)
# Out:
# Date             object
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year              int64
# region            int64
# dtype: object

# %%
df.drop('Date', inplace=True, axis=1)

# %%
df.drop('type', inplace=True, axis=1)

# %%
df.head()
# Out:
#    AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0          1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1          1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2          0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3          1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4          1.28      51039.60   941.48   43838.39   75.78     6183.95
#
#    Small Bags  Large Bags  XLarge Bags  year  region
# 0     8603.62       93.25          0.0  2015       0
# 1     9408.07       97.49          0.0  2015       0
# 2     8042.21      103.14          0.0  2015       0
# 3     5677.40      133.76          0.0  2015       0
# 4     5986.26      197.69          0.0  2015       0

# %%
#plotting the boxplot of each column to check the outliers 
df.plot(kind='box',subplots = True,layout=(4,5),figsize = (15,10))
# Out:
# AveragePrice        AxesSubplot(0.125,0.71587;0.133621x0.16413)
# Total Volume     AxesSubplot(0.285345,0.71587;0.133621x0.16413)
# 4046              AxesSubplot(0.44569,0.71587;0.133621x0.16413)
# 4225             AxesSubplot(0.606034,0.71587;0.133621x0.16413)
# 4770             AxesSubplot(0.766379,0.71587;0.133621x0.16413)
# Total Bags         AxesSubplot(0.125,0.518913;0.133621x0.16413)
# Small Bags      AxesSubplot(0.285345,0.518913;0.133621x0.16413)
# Large Bags       AxesSubplot(0.44569,0.518913;0.133621x0.16413)
# XLarge Bags     AxesSubplot(0.606034,0.518913;0.133621x0.16413)
# year            AxesSubplot(0.766379,0.518913;0.133621x0.16413)
# region             AxesSubplot(0.125,0.321957;0.133621x0.16413)
# dtype: object

# %%
#calculate the zscore
from scipy.stats import zscore

z = np.abs(zscore(df))
print(z)
# Out:
# [[1.35048079 0.34696593 0.33149016 ... 0.29272731 0.44100815 1.3143384 ]
#  [1.45639674 0.34907791 0.33167633 ... 0.29272731 0.44100815 1.3143384 ]
#  [0.76783831 0.33478463 0.33161448 ... 0.29272731 0.44100815 1.3143384 ]
#  ...
#  [2.14485045 0.32120275 0.30820887 ... 0.1820374  2.26753179 0.88028586]
#  [2.09189247 0.31878364 0.30423037 ... 0.29272731 2.26753179 0.88028586]
#  [1.88006056 0.3201721  0.30987728 ... 0.29272731 2.26753179 0.88028586]]

# %%
#checking the co-relation of all column to each other
df_cor = df.corr()
plt.figure(figsize=(30,25))
sns.heatmap(df_cor,annot=True)
plt.plot()
# Out:
# []

# %% [markdown]
# Both region and AveragePrice have good correlation with all the columns. Hence we can work with all the columns as seen above.

# %%
threshold = 3
print(np.where(z<3))
print(df.shape)
# Out:
# (array([   0,    0,    0, ..., 1516, 1516, 1516], dtype=int64), array([ 0,  1,  2, ...,  8,  9, 10], dtype=int64))
# (1517, 11)

# %%
#Assign the value to df_new which are less the threshold value and removing the outliers
df_new = df[(z<3).all(axis = 1)]

# %%
print(df.shape)
print(df_new.shape)
df = df_new
print('Shape after removing outlires',df.shape)
# Out:
# (1517, 11)
# (1436, 11)
# Shape after removing outlires (1436, 11)

# %%
#now finding the mean value of each column 
print(df['4225'].mean())
print(df['Total Bags'].mean())
print(df['Small Bags'].mean())
print(df['4046'].mean())
print(df['4770'].mean())
# Out:
# 357322.4631754874
# 161502.6083217268
# 136707.43429665748
# 360388.75383704784
# 28770.081894150393

# %%
import warnings
warnings.filterwarnings('ignore')

#replacing the outlier value to its mean value to remove outliers
df.loc[df['4225']<3,'4225'] = np.mean(df['4225'])
df.loc[df['Total Bags']<4.8,'Total Bags'] = np.mean(df['Total Bags'])
df.loc[df['Small Bags']<4,'Small Bags'] = np.mean(df['Small Bags'])
df.loc[df['4046']<3,'4046'] = np.mean(df['4046'])
df.loc[df['4770']<3,'4770'] = np.mean(df['4770'])

# %% [markdown]
# Lets train our model now

# %% [markdown]
# Lets split the dataset into training and testing data

# %%
from sklearn.model_selection import train_test_split
from sklearn import preprocessing

# %% [markdown]
# First lets predict the Average Price

# %%
X= df.drop(['AveragePrice'],axis=1)
Y=df['AveragePrice']
X = X.astype(int)
Y=Y.astype(int)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)

print(X_train.shape)
print(X_test.shape)
# Out:
# (1148, 10)
# (288, 10)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

# %%
log_reg=LogisticRegression(C=1000,max_iter=10000)
log_reg.fit(X_train,Y_train)
print('Logistic Regression:')
print('Traning Model accruracy scores: {:.3f}'.format(log_reg.score(X_train,Y_train)))
print('Test Model accruracy scores: {:.3f}'.format(log_reg.score(X_test,Y_test)))
# Out:
# Logistic Regression:
# Traning Model accruracy scores: 0.779
# Test Model accruracy scores: 0.771

# %% [markdown]
# Random Forest Classifier

# %%
m = RandomForestClassifier(n_jobs=2,random_state=1)
m.fit(X_train,Y_train)
m.score(X_train,Y_train)
# Out:
# 0.9912891986062717

# %% [markdown]
# Random Forest is the clear winner here with 99% accuracy. Lets Hypertune our model.

# %%
estimator = RandomForestRegressor()
param_grid = { "n_estimators" :[50,100,200] ,
               "max_features" : ["auto", "sqrt", "log2"] ,
               "bootstrap": [True, False] ,
               "min_samples_split" : [2,4,8]
             }
clf = GridSearchCV(estimator, param_grid, cv=5)
clf.fit(X_train,Y_train)
print(f"best parameters: {clf.best_params_}")
print(f"best score: {clf.score(X_train,Y_train)}")
# Out:
# best parameters: {'bootstrap': False, 'max_features': 'log2', 'min_samples_split': 8, 'n_estimators': 200}
# best score: 0.9514696460153692

# %%
#importing library for classification prediction
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix,roc_auc_score,roc_curve
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier,GradientBoostingClassifier
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

# %%
x= df.drop(['region'],axis=1)
y=df['region']
x = x.astype(int)
y= y.astype(int)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

print(x_train.shape)
print(x_test.shape)
# Out:
# (1148, 10)
# (288, 10)

# %%
models = []

models.append(("K-Nearest Neighbour:",KNeighborsClassifier(n_neighbors=3)))
models.append(("Decision Tree:",DecisionTreeClassifier()))
models.append(("Random Forest:",RandomForestClassifier(n_estimators=7)))
models.append(("AdaBoostClassifier:",AdaBoostClassifier()))
models.append(("GradientBoostingClassifier:",GradientBoostingClassifier()))

print('Models appended...')
# Out:
# Models appended...

# %%
results = []
names = []
for name,model in models:
    kfold = KFold(n_splits=10, random_state=0)
    cv_result = cross_val_score(model,x_train,y_train.values.ravel(), cv = kfold,scoring = "accuracy")
    names.append(name)
    results.append(cv_result)
for i in range(len(names)):
    print(names[i],results[i].mean()*100)
# Out:
# K-Nearest Neighbour: 81.62090007627766
# Decision Tree: 87.37299771167046
# Random Forest: 91.90160183066361
# AdaBoostClassifier: 16.10831426392067
# GradientBoostingClassifier: 87.28451563691839

# %% [markdown]
# Random Forest is the clear winner for predicting the region too.

# %% [markdown]
# Lets hypertune our model

# %%
estimator = RandomForestRegressor()
param_grid = { "n_estimators" :[50,100,200] ,
               "max_features" : ["auto", "sqrt", "log2"] ,
               "bootstrap": [True, False] ,
               "min_samples_split" : [2,4,8]
             }
rlf = GridSearchCV(estimator, param_grid, cv=5)
rlf.fit(x_train,y_train)
print(f"best parameters: {rlf.best_params_}")
print(f"best score: {rlf.score(x_train,y_train)}")
# Out:
# best parameters: {'bootstrap': False, 'max_features': 'log2', 'min_samples_split': 2, 'n_estimators': 200}
# best score: 1.0

# %%
#Saving the best model for future use
from sklearn.externals import joblib
joblib.dump(clf,'Avacado_Price.obj')
joblib.dump(rlf,'Avacado_Region.obj')
# Out:
# ['Avacado_Region.obj']
